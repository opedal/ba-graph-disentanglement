# %% [markdown]
# # Imports

# %%
## Network Processing
import networkx as nx 
from barabasi_albert import barabasi_albert_graph

## Visualization 
from matplotlib import pyplot as plt
import seaborn as sns

## Matrix Processing
import numpy as np
import pandas as pd
import scipy as sp

## GNN 
import tensorflow as tf
import keras.backend as K
from keras.models import Input, Model, Sequential
from keras.losses import MeanSquaredError
from keras.layers import Dense, Activation, Dropout, Lambda
from keras.callbacks import History, EarlyStopping
from multi_graph_cnn_layer import MultiGraphCNN

## Data Processing
from sklearn.utils import shuffle

## Tool functions
from utils import *
from tqdm import tqdm

## Error metrics
from sklearn.metrics import mean_squared_error

## Experiment metrics
from graph_scoring import GraphScorer

## Seed the pseudorandom number generator
from random import randint,seed

# %% [markdown]
# # CONSTANTS

# %%
# Specify whether to use a symmetric norm for the adjacency matrix or not
SYM_NORM = True 

# set 2 for standard BA model, 3 for non-linear BA model
NB_BARABASI_PARAM = 3 

# Choose 'standard' for 2 params, 'standard', 'alpha noise' or 'non-linear' for 3 params
EXPERIMENT = "non-linear" 

## Seed random number generator
SEED = 0
seed(SEED)

# %% [markdown]
# # TOOL FUNCTIONS

# %% [markdown]
# ### Data Generation

# %%
def generate_barabasi_adj_matrix(n, m, alpha,seed=None):
    """Generates a Barabasi Alert graph and returns an adjacency matrix with
     a node ordering defined by the networkx Graph library"""
    networkx_graph = barabasi_albert_graph(n, m, alpha,seed=seed)
    adj_matrix = nx.linalg.graphmatrix.adjacency_matrix(networkx_graph, nodelist=None, weight=None)
    return adj_matrix.todense()

# %%
def generate_BA_graphs_for_GNN(nb_graphs, n, train_size,NB_BARABASI_PARAM=2,exp_type = "standard",train=True):
    """Generates 'nb_graphs' Barabasi graphs. Each graph has the same number of nodes 'n', the first 
    parameter of the Barabasi-Albert model. The second parameter 'm' is randomly generated 
    in 1 <= m < n. The third parameter alpha is generated in 1/3 < alpha < 3.
    The function outputs the adjacency matrices, the feature matrices (identity matrices) 
    and the parameters n and m used in the data generation process"""
    
    # Each matrix generated during the graph generation process is vertically concatenated to the output
    adjacency_matrices = np.zeros((nb_graphs*n, n))
    feature_matrices = np.zeros((nb_graphs*n, n))
    parameter_vectors = np.zeros((nb_graphs, NB_BARABASI_PARAM))

    for sample_graph_index in tqdm(range(nb_graphs)):
        
        if train:
            set_seed=sample_graph_index
        else:
            set_seed=sample_graph_index + train_size
            
        np.random.seed(set_seed)
        seed(set_seed)
        
        # Choose m randomly s.t 1 <= m < n
        m = randint(1, n-1)
        
        # Choose alpha according to experiment type
        if exp_type == "standard":
            alpha = 1
        elif exp_type == "alpha noise":
            alpha = np.random.normal(1,0.1)
        elif exp_type == "non-linear":
            alpha = np.random.uniform(1/3, 3)
        elif isinstance(exp_type, str):
            raise ValueError
        else:
            raise TypeError

        # Generate Barabasi Graph adjacency matrix
        adj_matrix = generate_barabasi_adj_matrix(n, m, alpha, seed=set_seed)

        # Update output matrices
        row_start_index = n * sample_graph_index
        
        adjacency_matrices[row_start_index: row_start_index + n, :] = adj_matrix
        feature_matrices[row_start_index: row_start_index + n, :] = np.eye(n)
        if NB_BARABASI_PARAM == 2:
            parameter_vectors[sample_graph_index, :] = [n, m]
        elif NB_BARABASI_PARAM == 3:
            parameter_vectors[sample_graph_index, :] = [n, m, alpha]
    
    return adjacency_matrices, feature_matrices, parameter_vectors

# %%
def load_our_data(adjacency_matrices_file_name, feature_matrices_file_name, parameter_vectors_file_name,seed):
    """Loads the data and prepares it for input into the GNN"""
    
    # Load and prepare the adjacency matrices
    A = pd.read_csv(adjacency_matrices_file_name, header=None)
    A = np.array(A)
    num_graph_nodes = A.shape[1]
    num_graphs = int(A.shape[0]/A.shape[1])

    A = np.split(A, num_graphs, axis=0)
    A = np.array(A)

    # Load and prepare the feature matrices
    X = pd.read_csv(feature_matrices_file_name, header=None)
    X = np.array(X)
    X = np.split(X, num_graphs, axis=0)
    X = np.array(X)

    # Load and prepare the parameter vectors
    Y = pd.read_csv(parameter_vectors_file_name, header=None)
    Y = np.array(Y)

    # Shuffle data before training
    A, X, Y = shuffle(A, X, Y,random_state=seed)
    
    return A, X, Y

# %% [markdown]
# ### Multi GNN

# %%
def train_multi_gnn_model(A, X, Y, NB_BARABASI_PARAM=3,num_filters = 2):
    """Build and train a multi GNN network. A is the matrix of adjacency matrices
    vertically concatenated. X is the matrix of feature matrices vertically concatenated. Y is the matrix 
    of parameter matrices vertically concatenated"""
    
    # build graph_conv_filters
    graph_conv_filters = preprocess_adj_tensor_by_filter(A, num_filters, SYM_NORM)

    # build model
    X_input = Input(shape=(X.shape[1], X.shape[2]))
    graph_conv_filters_input = Input(shape=(graph_conv_filters.shape[1], graph_conv_filters.shape[2]))

    output = MultiGraphCNN(200, num_filters, activation='elu')([X_input, graph_conv_filters_input])
    output = Dropout(0.2)(output)
    output = MultiGraphCNN(200, num_filters, activation='elu')([output, graph_conv_filters_input])
    output = Dropout(0.2)(output)
    
    # adding a node invariant layer to make sure output does not depends upon the node order in a graph.
    output = Lambda(lambda x: K.mean(x, axis=1))(output) 
    
    output = Dense(256, activation="relu")(output)
    output = Dense(128, activation="relu")(output)
    output = Dense(64, activation="relu")(output)
    output = Dense(32, activation="relu")(output)
    output = Dense(16, activation="relu")(output)
    output = Dense(4, activation="relu")(output)
    output = Dense(NB_BARABASI_PARAM)(output)

    nb_epochs = 1000
    batch_size = 64
    history = History()
    early_stopping = EarlyStopping(patience = 10)

    model = Model(inputs=[X_input, graph_conv_filters_input], outputs=output)
    
    model.compile(loss="mse", optimizer='adam')
    model.fit([X, graph_conv_filters], Y, batch_size=batch_size, validation_split=0.1, \
              epochs=nb_epochs, shuffle=True, verbose=1,callbacks=[history, early_stopping])
    
    return model, history.history

# %% [markdown]
# # Main

# %% [markdown]
# ### Generate train & test data

# %%
# Instantiate parameters
train_size = 16000
test_size = 4000
NUMBER_OF_NODES = 50
NUM_FILTERS = 3
NB_BARABASI_PARAM = 3

# %%
# Generate [train_size] graphs of [NUMBER_OF_NODES] nodes train data

adjacency_matrices_train, feature_matrices_train, parameter_vectors_train = \
    generate_BA_graphs_for_GNN(nb_graphs=train_size,
                               n=NUMBER_OF_NODES, 
                               train_size=train_size,
                               NB_BARABASI_PARAM=NB_BARABASI_PARAM,
                               exp_type = EXPERIMENT,
                               train=True)
# Out:
# 100%|██████████| 16/16 [00:00<00:00, 28.19it/s]

# %%
# Generate [test_size] graphs of [NUMBER_OF_NODES] nodes test data
adjacency_matrices_test, feature_matrices_test, parameter_vectors_test = \
    generate_BA_graphs_for_GNN(nb_graphs=test_size,
                               n=NUMBER_OF_NODES, 
                               train_size=train_size,
                               NB_BARABASI_PARAM=NB_BARABASI_PARAM,
                               exp_type = EXPERIMENT,
                               train=False)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 22.89it/s]

# %%
# Save data
# Since graph generation is computationally expensive
np.savetxt('adjacency_matrices_train.csv', adjacency_matrices_train, delimiter=',')
np.savetxt('feature_matrices_train.csv', feature_matrices_train, delimiter=',')
np.savetxt('parameter_vectors_train.csv', parameter_vectors_train, delimiter=',')

np.savetxt('adjacency_matrices_test.csv', adjacency_matrices_test, delimiter=',')
np.savetxt('feature_matrices_test.csv', feature_matrices_test, delimiter=',')
np.savetxt('parameter_vectors_test.csv', parameter_vectors_test, delimiter=',')

# %% [markdown]
# ## Random Forest
# Run a random forest model on extracted feature vectors, to predict the BA parameters n, m, alpha.

# %% [markdown]
# Feature Extraction:

# %%
NUM_RF_TRAIN = 600
NUM_RF_TEST = 400

# %%
from predict_params import GraphScorer, preprocess, get_rf_grid, ParamPredictor
from generate_data import generate_ba_nx_graphs, generate_er_nx_graphs

from sklearn.metrics import accuracy_score, mean_absolute_error, recall_score, precision_score, mean_squared_error

scorer = GraphScorer()

Xraw, y = generate_ba_nx_graphs(num_graphs=NUM_RF_TRAIN,n=NUMBER_OF_NODES,num_ba_params=NB_BARABASI_PARAM)
Xraw_tst, ytst = generate_ba_nx_graphs(num_graphs=NUM_RF_TEST,n=NUMBER_OF_NODES,num_ba_params=NB_BARABASI_PARAM)

X = preprocess(Xraw, scorer)
Xtst = preprocess(Xraw_tst, scorer)

# %% [markdown]
# Build & Train Model:

# %%
model = get_rf_grid()
predictor = ParamPredictor(model=model, model_name='random_forest')
predictor.fit_model(X, y)

# %% [markdown]
# Predict & Print Losses:

# %%
yprd = predictor.predict_params(Xtst)

n_pred, m_pred, alpha_pred = yprd[:,0], yprd[:,1], yprd[:,2]
n_true,m_true,alpha_true = ytst[:,0],ytst[:,1],ytst[:,2]

print("current model is ",predictor.model_name)
print("total mse is ", mean_squared_error(yprd, ytst))
print("mse for n is ", mean_squared_error(n_pred, n_true))
print("mse for m is ", mean_squared_error(m_pred, m_true))
print("mse for alpha is ", mean_squared_error(alpha_pred, alpha_true))
print("mean absolute error for alpha is ", mean_absolute_error(alpha_pred, alpha_true))
# Out:
# current model is  random_forest
# total mse is  0.3622077931475318
# mse for n is  0.0
# mse for m is  0.7353483439641798
# mse for alpha is  0.35127503547841604
# mean absolute error for alpha is  0.47435048004278935

# %%
# print pearson correlation 
# Remark: The correlation reported in the paper is a bit higher (0.8),
# because it was obtained by training on a larger dataset on the cluster. 

from scipy.stats import pearsonr

r, _ = pearsonr(alpha_true, alpha_pred)
print("pearson r correlation between true and predicted alpha is ",r)
# Out:
# pearson r correlation between true and predicted alpha is  0.7221059052434465

# %%
# plot histogram of true and predicted alpha values 
# we can see the histograms are very close
alphas = [alpha_pred, alpha_true]
    
plt.hist(alphas, 22, histtype='bar',color=['deepskyblue','xkcd:saffron'], label=['pred','true'])
plt.title("alpha histograms for "+predictor.model_name)
plt.savefig("alpha_hists_"+predictor.model_name + ".png")

# %%
# plot true versus predicted alphas
# we see an almost linear correlation 
plt.scatter(x=ytst[:, 2], y=yprd[:, 2],color="deepskyblue")
plt.ylabel("predicted alpha")
plt.xlabel("true alpha")
plt.title("true versus predicted alpha for "+predictor.model_name)
plt.savefig("predicted_alpha_"+predictor.model_name + ".png")

# %% [markdown]
# ### Train GNN Encoder

# %%
SEED = 0
np.random.seed(SEED)
tf.random.set_seed(SEED)
seed(SEED)
# Load Train data
A_train, X_train, Y_train = \
        load_our_data('adjacency_matrices_train.csv', 'feature_matrices_train.csv', 'parameter_vectors_train.csv',seed=SEED)

# Train
model, hist = train_multi_gnn_model(A_train,
                                    X_train, 
                                    Y_train, 
                                    NB_BARABASI_PARAM=NB_BARABASI_PARAM, 
                                    num_filters=NUM_FILTERS)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 199ms/step - loss: 998.3730 - val_loss: 1260.4735
# Epoch 2/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 998.2694 - val_loss: 1260.3738
# Epoch 3/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 998.1854 - val_loss: 1260.3428
# Epoch 4/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 998.1595 - val_loss: 1260.1763
# Epoch 5/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 998.0269 - val_loss: 1260.0824
# Epoch 6/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 997.9487 - val_loss: 1259.9758
# Epoch 7/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 997.8454 - val_loss: 1259.8865
# Epoch 8/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 997.7472 - val_loss: 1259.7496
# Epoch 9/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 997.6268 - val_loss: 1259.5640
# Epoch 10/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 997.4893 - val_loss: 1259.3096
# Epoch 11/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 997.3036 - val_loss: 1259.0430
# Epoch 12/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 997.1012 - val_loss: 1258.6744
# Epoch 13/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 996.8000 - val_loss: 1258.3116
# Epoch 14/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 996.4375 - val_loss: 1257.7715
# Epoch 15/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 995.9580 - val_loss: 1256.9489
# Epoch 16/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 995.2841 - val_loss: 1255.7664
# Epoch 17/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 994.3796 - val_loss: 1254.0649
# Epoch 18/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 993.0712 - val_loss: 1252.1536
# Epoch 19/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 991.6104 - val_loss: 1249.4495
# Epoch 20/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 989.4240 - val_loss: 1245.9561
# Epoch 21/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 986.5759 - val_loss: 1241.8234
# Epoch 22/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 983.1661 - val_loss: 1236.2997
# Epoch 23/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 978.9223 - val_loss: 1229.2620
# Epoch 24/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 973.8759 - val_loss: 1220.5166
# Epoch 25/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 967.9545 - val_loss: 1210.6199
# Epoch 26/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 962.3503 - val_loss: 1201.6440
# Epoch 27/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 958.6680 - val_loss: 1196.1415
# Epoch 28/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 960.0737 - val_loss: 1194.9464
# Epoch 29/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 962.8738 - val_loss: 1193.5826
# Epoch 30/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 961.7719 - val_loss: 1192.2893
# Epoch 31/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 957.8599 - val_loss: 1192.4731
# Epoch 32/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 954.9505 - val_loss: 1194.1106
# Epoch 33/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 953.6600 - val_loss: 1195.7124
# Epoch 34/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 953.3762 - val_loss: 1196.7213
# Epoch 35/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 953.2210 - val_loss: 1196.7568
# Epoch 36/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 952.8627 - val_loss: 1195.6559
# Epoch 37/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 952.0504 - val_loss: 1193.4414
# Epoch 38/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 950.6922 - val_loss: 1190.3265
# Epoch 39/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 949.0466 - val_loss: 1186.6278
# Epoch 40/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 947.3749 - val_loss: 1182.7731
# Epoch 41/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 945.8827 - val_loss: 1179.2051
# Epoch 42/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 944.8717 - val_loss: 1176.2798
# Epoch 43/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 944.2188 - val_loss: 1174.0376
# Epoch 44/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 943.4911 - val_loss: 1172.3582
# Epoch 45/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 942.4399 - val_loss: 1171.1859
# Epoch 46/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 940.9064 - val_loss: 1170.5435
# Epoch 47/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 939.4976 - val_loss: 1170.3514
# Epoch 48/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 938.1732 - val_loss: 1170.2863
# Epoch 49/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 937.0757 - val_loss: 1169.9088
# Epoch 50/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 936.0960 - val_loss: 1168.8745
# Epoch 51/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 935.0034 - val_loss: 1167.0736
# Epoch 52/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 933.7778 - val_loss: 1164.5406
# Epoch 53/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 932.4362 - val_loss: 1161.5092
# Epoch 54/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 931.0737 - val_loss: 1158.2843
# Epoch 55/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 929.6603 - val_loss: 1155.2117
# Epoch 56/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 928.4605 - val_loss: 1152.5497
# Epoch 57/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 927.1730 - val_loss: 1150.3589
# Epoch 58/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 926.1246 - val_loss: 1148.6681
# Epoch 59/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 924.7834 - val_loss: 1147.4192
# Epoch 60/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 923.2701 - val_loss: 1146.4637
# Epoch 61/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 921.9116 - val_loss: 1145.5459
# Epoch 62/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 920.5486 - val_loss: 1144.3030
# Epoch 63/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 919.3920 - val_loss: 1142.5515
# Epoch 64/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 917.9224 - val_loss: 1140.2296
# Epoch 65/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 916.4534 - val_loss: 1137.4751
# Epoch 66/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 915.1181 - val_loss: 1134.4927
# Epoch 67/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 913.5426 - val_loss: 1131.5815
# Epoch 68/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 912.0541 - val_loss: 1128.9412
# Epoch 69/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 910.6582 - val_loss: 1126.6935
# Epoch 70/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 909.3247 - val_loss: 1124.8285
# Epoch 71/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 907.8111 - val_loss: 1123.2461
# Epoch 72/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 906.3076 - val_loss: 1121.7208
# Epoch 73/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 904.7188 - val_loss: 1120.0447
# Epoch 74/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 903.2737 - val_loss: 1118.0425
# Epoch 75/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 901.7120 - val_loss: 1115.6215
# Epoch 76/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 900.2484 - val_loss: 1112.8583
# Epoch 77/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 898.6120 - val_loss: 1109.9291
# Epoch 78/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 896.9565 - val_loss: 1107.0625
# Epoch 79/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 895.4791 - val_loss: 1104.4342
# Epoch 80/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 893.9009 - val_loss: 1102.1482
# Epoch 81/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 892.3478 - val_loss: 1100.0347
# Epoch 82/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 890.6292 - val_loss: 1097.9221
# Epoch 83/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 888.8659 - val_loss: 1095.7543
# Epoch 84/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 887.2296 - val_loss: 1093.4810
# Epoch 85/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 885.5423 - val_loss: 1090.9327
# Epoch 86/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 883.6932 - val_loss: 1088.1018
# Epoch 87/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 882.1000 - val_loss: 1085.1110
# Epoch 88/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 880.4605 - val_loss: 1082.1652
# Epoch 89/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 878.4459 - val_loss: 1079.4580
# Epoch 90/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 876.8407 - val_loss: 1076.9359
# Epoch 91/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 875.1406 - val_loss: 1074.5312
# Epoch 92/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 873.4147 - val_loss: 1072.1948
# Epoch 93/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 871.4717 - val_loss: 1069.5841
# Epoch 94/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 869.5423 - val_loss: 1066.7605
# Epoch 95/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 867.7397 - val_loss: 1063.7400
# Epoch 96/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 865.8513 - val_loss: 1060.6873
# Epoch 97/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 864.0405 - val_loss: 1057.6746
# Epoch 98/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 861.9517 - val_loss: 1054.8439
# Epoch 99/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 860.1569 - val_loss: 1052.1023
# Epoch 100/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 858.3661 - val_loss: 1049.2950
# Epoch 101/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 856.5200 - val_loss: 1046.4316
# Epoch 102/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 854.4299 - val_loss: 1043.4712
# Epoch 103/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 852.3581 - val_loss: 1040.5327
# Epoch 104/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 850.4132 - val_loss: 1037.3835
# Epoch 105/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 848.3773 - val_loss: 1034.1968
# Epoch 106/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 846.3071 - val_loss: 1031.0852
# Epoch 107/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 844.3482 - val_loss: 1027.9009
# Epoch 108/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 842.1498 - val_loss: 1024.7607
# Epoch 109/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 840.1288 - val_loss: 1021.5187
# Epoch 110/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 838.0865 - val_loss: 1018.1670
# Epoch 111/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 835.9249 - val_loss: 1014.6260
# Epoch 112/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 833.8781 - val_loss: 1011.2817
# Epoch 113/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 831.6607 - val_loss: 1008.2759
# Epoch 114/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 829.5048 - val_loss: 1005.2417
# Epoch 115/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 827.3150 - val_loss: 1002.2660
# Epoch 116/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 825.0228 - val_loss: 998.7910
# Epoch 117/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 822.9952 - val_loss: 994.9707
# Epoch 118/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 820.5782 - val_loss: 991.3198
# Epoch 119/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 818.5928 - val_loss: 987.8756
# Epoch 120/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 816.2164 - val_loss: 984.8015
# Epoch 121/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 814.0628 - val_loss: 981.6886
# Epoch 122/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 811.7936 - val_loss: 978.0840
# Epoch 123/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 809.5192 - val_loss: 974.2230
# Epoch 124/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 807.2465 - val_loss: 970.7124
# Epoch 125/1000
# 1/1 [==============================] - 0s 47ms/step - loss: 804.9745 - val_loss: 967.4625
# Epoch 126/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 802.6721 - val_loss: 964.2590
# Epoch 127/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 800.4193 - val_loss: 960.8149
# Epoch 128/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 798.1362 - val_loss: 957.1743
# Epoch 129/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 795.9128 - val_loss: 953.5762
# Epoch 130/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 793.6408 - val_loss: 950.1774
# Epoch 131/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 791.3701 - val_loss: 946.9338
# Epoch 132/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 788.9818 - val_loss: 943.6147
# Epoch 133/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 786.9066 - val_loss: 939.8642
# Epoch 134/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 784.3555 - val_loss: 936.4309
# Epoch 135/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 782.3036 - val_loss: 933.0575
# Epoch 136/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 779.5988 - val_loss: 930.0228
# Epoch 137/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 777.4450 - val_loss: 926.3375
# Epoch 138/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 774.9120 - val_loss: 922.4884
# Epoch 139/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 772.4730 - val_loss: 918.9611
# Epoch 140/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 770.2129 - val_loss: 915.5795
# Epoch 141/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 767.7087 - val_loss: 912.6621
# Epoch 142/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 765.4127 - val_loss: 909.0178
# Epoch 143/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 763.0117 - val_loss: 904.8555
# Epoch 144/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 760.4114 - val_loss: 901.2368
# Epoch 145/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 758.3453 - val_loss: 897.9312
# Epoch 146/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 755.5334 - val_loss: 895.1461
# Epoch 147/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 753.2183 - val_loss: 891.4087
# Epoch 148/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 750.7269 - val_loss: 886.9891
# Epoch 149/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 748.1790 - val_loss: 883.2415
# Epoch 150/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 745.9601 - val_loss: 880.1893
# Epoch 151/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 743.1261 - val_loss: 877.6712
# Epoch 152/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 740.9466 - val_loss: 873.3105
# Epoch 153/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 738.1017 - val_loss: 868.8439
# Epoch 154/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 735.6367 - val_loss: 865.0411
# Epoch 155/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 733.3395 - val_loss: 861.8606
# Epoch 156/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 730.5724 - val_loss: 859.5387
# Epoch 157/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 728.2914 - val_loss: 855.6433
# Epoch 158/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 725.7954 - val_loss: 850.5687
# Epoch 159/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 722.9224 - val_loss: 846.5367
# Epoch 160/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 720.9325 - val_loss: 843.4772
# Epoch 161/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 717.8118 - val_loss: 841.1263
# Epoch 162/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 715.5970 - val_loss: 836.7228
# Epoch 163/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 712.7358 - val_loss: 831.8853
# Epoch 164/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 710.2866 - val_loss: 828.0747
# Epoch 165/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 707.6689 - val_loss: 825.1441
# Epoch 166/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 704.9923 - val_loss: 821.7355
# Epoch 167/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 702.4485 - val_loss: 817.2849
# Epoch 168/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 699.7642 - val_loss: 813.2819
# Epoch 169/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 697.1836 - val_loss: 809.9200
# Epoch 170/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 694.6078 - val_loss: 806.8441
# Epoch 171/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 692.1074 - val_loss: 802.4392
# Epoch 172/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 689.3779 - val_loss: 798.0063
# Epoch 173/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 686.8063 - val_loss: 794.2435
# Epoch 174/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 684.2154 - val_loss: 791.3244
# Epoch 175/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 681.5689 - val_loss: 787.7256
# Epoch 176/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 678.8566 - val_loss: 783.3066
# Epoch 177/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 676.1343 - val_loss: 779.3711
# Epoch 178/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 673.5452 - val_loss: 775.6882
# Epoch 179/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 670.9179 - val_loss: 772.5162
# Epoch 180/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 668.3976 - val_loss: 768.8560
# Epoch 181/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 665.7232 - val_loss: 764.2130
# Epoch 182/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 662.9833 - val_loss: 760.1827
# Epoch 183/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 660.6899 - val_loss: 757.0782
# Epoch 184/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 657.6581 - val_loss: 754.3779
# Epoch 185/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 655.2812 - val_loss: 749.8617
# Epoch 186/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 652.4010 - val_loss: 745.1368
# Epoch 187/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 649.9166 - val_loss: 741.4277
# Epoch 188/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 647.2230 - val_loss: 738.7425
# Epoch 189/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 644.4880 - val_loss: 735.1665
# Epoch 190/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 641.8231 - val_loss: 730.5397
# Epoch 191/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 639.0873 - val_loss: 726.4155
# Epoch 192/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 636.5509 - val_loss: 723.0774
# Epoch 193/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 633.7496 - val_loss: 719.9144
# Epoch 194/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 631.1503 - val_loss: 715.7709
# Epoch 195/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 628.3796 - val_loss: 711.6605
# Epoch 196/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 625.8149 - val_loss: 707.8416
# Epoch 197/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 623.0807 - val_loss: 704.4377
# Epoch 198/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 620.4469 - val_loss: 700.7849
# Epoch 199/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 617.7880 - val_loss: 697.2330
# Epoch 200/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 615.1205 - val_loss: 693.3074
# Epoch 201/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 612.4536 - val_loss: 689.1392
# Epoch 202/1000
# 1/1 [==============================] - 0s 167ms/step - loss: 609.8350 - val_loss: 685.4894
# Epoch 203/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 607.2020 - val_loss: 682.3641
# Epoch 204/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 604.4923 - val_loss: 678.8304
# Epoch 205/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 601.8394 - val_loss: 674.6083
# Epoch 206/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 599.1947 - val_loss: 671.0001
# Epoch 207/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 596.4859 - val_loss: 667.4740
# Epoch 208/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 593.8478 - val_loss: 663.8291
# Epoch 209/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 591.2035 - val_loss: 660.1627
# Epoch 210/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 588.5707 - val_loss: 656.3337
# Epoch 211/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 585.8952 - val_loss: 652.7217
# Epoch 212/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 583.2811 - val_loss: 648.6476
# Epoch 213/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 580.7183 - val_loss: 645.5846
# Epoch 214/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 577.9481 - val_loss: 642.2106
# Epoch 215/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 575.3503 - val_loss: 638.3816
# Epoch 216/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 572.6826 - val_loss: 634.2736
# Epoch 217/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 570.1214 - val_loss: 630.9532
# Epoch 218/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 567.4206 - val_loss: 627.4540
# Epoch 219/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 564.7851 - val_loss: 623.6298
# Epoch 220/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 562.2430 - val_loss: 620.4122
# Epoch 221/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 559.6301 - val_loss: 616.3779
# Epoch 222/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 557.0181 - val_loss: 613.3807
# Epoch 223/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 554.2934 - val_loss: 610.1058
# Epoch 224/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 551.6865 - val_loss: 606.1304
# Epoch 225/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 549.0515 - val_loss: 602.1250
# Epoch 226/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 546.5284 - val_loss: 599.0364
# Epoch 227/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 543.8231 - val_loss: 595.6140
# Epoch 228/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 541.2197 - val_loss: 592.1042
# Epoch 229/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 538.6412 - val_loss: 588.2961
# Epoch 230/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 536.1147 - val_loss: 585.2188
# Epoch 231/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 533.5062 - val_loss: 582.2283
# Epoch 232/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 530.9647 - val_loss: 577.9309
# Epoch 233/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 528.2977 - val_loss: 574.1764
# Epoch 234/1000
# 1/1 [==============================] - ETA: 0s - loss: 525.756 - 0s 28ms/step - loss: 525.7569 - val_loss: 571.2979
# Epoch 235/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 523.1072 - val_loss: 568.6307
# Epoch 236/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 520.7128 - val_loss: 564.0917
# Epoch 237/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 518.0651 - val_loss: 560.6902
# Epoch 238/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 515.4461 - val_loss: 557.9359
# Epoch 239/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 512.9498 - val_loss: 554.7496
# Epoch 240/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 510.4348 - val_loss: 550.4440
# Epoch 241/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 507.9536 - val_loss: 547.7675
# Epoch 242/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 505.2017 - val_loss: 544.9677
# Epoch 243/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 502.7134 - val_loss: 540.7194
# Epoch 244/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 500.0900 - val_loss: 536.9768
# Epoch 245/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 497.7755 - val_loss: 535.0696
# Epoch 246/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 495.1594 - val_loss: 532.2037
# Epoch 247/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 492.6461 - val_loss: 527.2402
# Epoch 248/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 490.0496 - val_loss: 523.6506
# Epoch 249/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 487.7376 - val_loss: 521.7948
# Epoch 250/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 485.1178 - val_loss: 518.9442
# Epoch 251/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 482.6217 - val_loss: 514.2804
# Epoch 252/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 480.0972 - val_loss: 510.8899
# Epoch 253/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 477.6688 - val_loss: 509.3774
# Epoch 254/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 475.2386 - val_loss: 505.4424
# Epoch 255/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 472.4827 - val_loss: 501.2416
# Epoch 256/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 470.2431 - val_loss: 498.5927
# Epoch 257/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 467.5091 - val_loss: 497.2907
# Epoch 258/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 465.1840 - val_loss: 493.2499
# Epoch 259/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 462.5492 - val_loss: 488.6745
# Epoch 260/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 460.3770 - val_loss: 485.9955
# Epoch 261/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 457.6005 - val_loss: 484.6459
# Epoch 262/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 455.3715 - val_loss: 480.5502
# Epoch 263/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 452.6440 - val_loss: 476.5016
# Epoch 264/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 450.4010 - val_loss: 473.9642
# Epoch 265/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 447.7788 - val_loss: 472.5456
# Epoch 266/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 445.6469 - val_loss: 468.1061
# Epoch 267/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 442.8889 - val_loss: 464.4390
# Epoch 268/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 440.4936 - val_loss: 461.8661
# Epoch 269/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 438.0324 - val_loss: 460.3031
# Epoch 270/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 435.8152 - val_loss: 456.3536
# Epoch 271/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 433.1216 - val_loss: 452.8356
# Epoch 272/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 430.8013 - val_loss: 450.0471
# Epoch 273/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 428.3269 - val_loss: 447.7601
# Epoch 274/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 426.0121 - val_loss: 444.3171
# Epoch 275/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 423.5578 - val_loss: 440.8724
# Epoch 276/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 421.1287 - val_loss: 437.8594
# Epoch 277/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 418.9726 - val_loss: 436.5256
# Epoch 278/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 416.5815 - val_loss: 433.3688
# Epoch 279/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 414.1641 - val_loss: 429.2040
# Epoch 280/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 412.0547 - val_loss: 427.0028
# Epoch 281/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 409.2552 - val_loss: 425.4686
# Epoch 282/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 407.2331 - val_loss: 421.3439
# Epoch 283/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 404.5698 - val_loss: 418.2709
# Epoch 284/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 402.2358 - val_loss: 416.1269
# Epoch 285/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 399.8195 - val_loss: 413.4142
# Epoch 286/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 397.5327 - val_loss: 410.0346
# Epoch 287/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 395.2985 - val_loss: 408.1085
# Epoch 288/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 392.8479 - val_loss: 405.9073
# Epoch 289/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 390.8293 - val_loss: 401.6380
# Epoch 290/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 388.5047 - val_loss: 399.3386
# Epoch 291/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 385.9024 - val_loss: 397.9117
# Epoch 292/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 383.7688 - val_loss: 394.6104
# Epoch 293/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 381.2994 - val_loss: 391.5636
# Epoch 294/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 379.0467 - val_loss: 388.6530
# Epoch 295/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 376.8056 - val_loss: 386.8439
# Epoch 296/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 374.4399 - val_loss: 384.5107
# Epoch 297/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 372.2240 - val_loss: 381.4489
# Epoch 298/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 369.8437 - val_loss: 378.4495
# Epoch 299/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 367.6576 - val_loss: 376.5906
# Epoch 300/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 365.3029 - val_loss: 374.8141
# Epoch 301/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 363.2712 - val_loss: 370.8483
# Epoch 302/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 360.8438 - val_loss: 368.1328
# Epoch 303/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 358.8387 - val_loss: 367.2301
# Epoch 304/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 356.4388 - val_loss: 364.5840
# Epoch 305/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 354.1281 - val_loss: 361.2141
# Epoch 306/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 351.8987 - val_loss: 358.5403
# Epoch 307/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 349.7529 - val_loss: 357.5270
# Epoch 308/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 347.6085 - val_loss: 354.2267
# Epoch 309/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 345.1837 - val_loss: 351.0252
# Epoch 310/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 343.0702 - val_loss: 348.8795
# Epoch 311/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 340.8870 - val_loss: 347.5022
# Epoch 312/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 338.6006 - val_loss: 345.6161
# Epoch 313/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 336.5728 - val_loss: 341.9621
# Epoch 314/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 334.2585 - val_loss: 339.1779
# Epoch 315/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 332.2297 - val_loss: 337.5637
# Epoch 316/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 329.9294 - val_loss: 335.4602
# Epoch 317/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 327.7737 - val_loss: 332.7001
# Epoch 318/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 325.6075 - val_loss: 330.0418
# Epoch 319/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 323.6838 - val_loss: 328.9321
# Epoch 320/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 321.3451 - val_loss: 327.5778
# Epoch 321/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 319.4841 - val_loss: 323.4816
# Epoch 322/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 317.1287 - val_loss: 320.8533
# Epoch 323/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 315.2888 - val_loss: 320.1977
# Epoch 324/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 312.9917 - val_loss: 318.0259
# Epoch 325/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 310.8826 - val_loss: 314.4438
# Epoch 326/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 308.7962 - val_loss: 312.4034
# Epoch 327/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 306.7021 - val_loss: 312.2772
# Epoch 328/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 304.8039 - val_loss: 309.0214
# Epoch 329/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 302.4837 - val_loss: 305.8115
# Epoch 330/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 300.6912 - val_loss: 304.7512
# Epoch 331/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 298.2618 - val_loss: 304.4386
# Epoch 332/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 296.8655 - val_loss: 299.7788
# Epoch 333/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 294.3428 - val_loss: 297.5284
# Epoch 334/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 292.4520 - val_loss: 297.3830
# Epoch 335/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 290.3282 - val_loss: 295.2885
# Epoch 336/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 288.2887 - val_loss: 291.6859
# Epoch 337/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 286.1585 - val_loss: 289.5112
# Epoch 338/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 284.2892 - val_loss: 288.8847
# Epoch 339/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 282.1780 - val_loss: 287.2243
# Epoch 340/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 280.2366 - val_loss: 283.8200
# Epoch 341/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 278.1675 - val_loss: 281.5450
# Epoch 342/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 276.4610 - val_loss: 280.9399
# Epoch 343/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 274.2661 - val_loss: 280.0269
# Epoch 344/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 272.8284 - val_loss: 275.7499
# Epoch 345/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 270.7650 - val_loss: 274.0989
# Epoch 346/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 268.5783 - val_loss: 274.6463
# Epoch 347/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 266.8300 - val_loss: 271.9102
# Epoch 348/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 264.7141 - val_loss: 268.2473
# Epoch 349/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 263.1696 - val_loss: 266.7578
# Epoch 350/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 260.7309 - val_loss: 266.8377
# Epoch 351/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 259.1647 - val_loss: 263.9041
# Epoch 352/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 256.9532 - val_loss: 261.1017
# Epoch 353/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 255.4463 - val_loss: 260.1597
# Epoch 354/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 253.1945 - val_loss: 259.9995
# Epoch 355/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 251.5144 - val_loss: 257.0811
# Epoch 356/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 249.5672 - val_loss: 254.0825
# Epoch 357/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 248.0728 - val_loss: 252.9814
# Epoch 358/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 245.9633 - val_loss: 253.2397
# Epoch 359/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 244.4695 - val_loss: 249.7024
# Epoch 360/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 242.1644 - val_loss: 247.3171
# Epoch 361/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 240.5655 - val_loss: 245.9409
# Epoch 362/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 238.5596 - val_loss: 245.2569
# Epoch 363/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 236.8932 - val_loss: 243.2847
# Epoch 364/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 235.0365 - val_loss: 240.8880
# Epoch 365/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 233.3974 - val_loss: 239.7321
# Epoch 366/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 231.4745 - val_loss: 238.6055
# Epoch 367/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 229.7414 - val_loss: 236.5518
# Epoch 368/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 227.9995 - val_loss: 235.0079
# Epoch 369/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 226.2360 - val_loss: 233.5415
# Epoch 370/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 224.5655 - val_loss: 231.9836
# Epoch 371/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 222.8134 - val_loss: 230.5572
# Epoch 372/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 221.1122 - val_loss: 228.8185
# Epoch 373/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 219.4069 - val_loss: 227.0830
# Epoch 374/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 217.7597 - val_loss: 225.9339
# Epoch 375/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 216.1015 - val_loss: 225.7844
# Epoch 376/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 214.7749 - val_loss: 222.9654
# Epoch 377/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 212.7677 - val_loss: 221.0598
# Epoch 378/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 211.4143 - val_loss: 220.7095
# Epoch 379/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 209.6660 - val_loss: 219.5752
# Epoch 380/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 208.0293 - val_loss: 216.8757
# Epoch 381/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 206.3475 - val_loss: 215.3015
# Epoch 382/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 204.9447 - val_loss: 215.3443
# Epoch 383/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 203.2511 - val_loss: 213.8821
# Epoch 384/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 201.7466 - val_loss: 211.1778
# Epoch 385/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 200.3203 - val_loss: 210.3717
# Epoch 386/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 198.4187 - val_loss: 211.1045
# Epoch 387/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 197.3987 - val_loss: 207.8877
# Epoch 388/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 195.3485 - val_loss: 205.8014
# Epoch 389/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 194.5113 - val_loss: 205.3845
# Epoch 390/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 192.2444 - val_loss: 205.8485
# Epoch 391/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 191.3186 - val_loss: 202.4477
# Epoch 392/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 189.3161 - val_loss: 200.6884
# Epoch 393/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 188.3703 - val_loss: 200.7816
# Epoch 394/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 186.3363 - val_loss: 201.2767
# Epoch 395/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 185.6876 - val_loss: 197.2418
# Epoch 396/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 183.4198 - val_loss: 195.7542
# Epoch 397/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 182.8412 - val_loss: 196.6171
# Epoch 398/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 180.7897 - val_loss: 196.2301
# Epoch 399/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 179.7853 - val_loss: 192.2764
# Epoch 400/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 178.1360 - val_loss: 191.1856
# Epoch 401/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 176.4303 - val_loss: 191.8335
# Epoch 402/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 175.0517 - val_loss: 190.8227
# Epoch 403/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 173.7728 - val_loss: 187.7270
# Epoch 404/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 172.1289 - val_loss: 186.4418
# Epoch 405/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 171.1673 - val_loss: 186.5419
# Epoch 406/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 169.4182 - val_loss: 186.4363
# Epoch 407/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 168.4243 - val_loss: 183.4797
# Epoch 408/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 166.6654 - val_loss: 182.0445
# Epoch 409/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 166.0381 - val_loss: 181.6502
# Epoch 410/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 164.0097 - val_loss: 183.4763
# Epoch 411/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 163.6565 - val_loss: 180.1868
# Epoch 412/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 161.4986 - val_loss: 177.7870
# Epoch 413/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 160.6051 - val_loss: 176.8133
# Epoch 414/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 159.2940 - val_loss: 178.5265
# Epoch 415/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 158.2582 - val_loss: 176.9946
# Epoch 416/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 156.7135 - val_loss: 173.7821
# Epoch 417/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 155.3893 - val_loss: 172.7469
# Epoch 418/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 154.3507 - val_loss: 173.6499
# Epoch 419/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 152.9652 - val_loss: 172.9628
# Epoch 420/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 151.7815 - val_loss: 170.0844
# Epoch 421/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 150.2925 - val_loss: 168.8268
# Epoch 422/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 149.6588 - val_loss: 168.7267
# Epoch 423/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 147.8230 - val_loss: 169.5291
# Epoch 424/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 147.3098 - val_loss: 166.8508
# Epoch 425/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 145.5078 - val_loss: 165.1173
# Epoch 426/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 144.6816 - val_loss: 164.5122
# Epoch 427/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 143.3188 - val_loss: 165.8452
# Epoch 428/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 142.4995 - val_loss: 164.1915
# Epoch 429/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 141.1205 - val_loss: 161.6207
# Epoch 430/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 140.0501 - val_loss: 160.7206
# Epoch 431/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 138.9210 - val_loss: 161.1356
# Epoch 432/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 137.7151 - val_loss: 160.8283
# Epoch 433/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 136.8256 - val_loss: 158.3382
# Epoch 434/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 135.5439 - val_loss: 157.1971
# Epoch 435/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 134.5724 - val_loss: 156.7799
# Epoch 436/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 133.3630 - val_loss: 157.4043
# Epoch 437/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 132.6892 - val_loss: 155.5247
# Epoch 438/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 131.1841 - val_loss: 153.8847
# Epoch 439/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 130.6835 - val_loss: 153.7958
# Epoch 440/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 129.1473 - val_loss: 153.8674
# Epoch 441/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 128.2872 - val_loss: 152.3409
# Epoch 442/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 127.1241 - val_loss: 150.7975
# Epoch 443/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 126.3106 - val_loss: 150.2960
# Epoch 444/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 125.1240 - val_loss: 150.3569
# Epoch 445/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 124.2455 - val_loss: 149.6051
# Epoch 446/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 123.2235 - val_loss: 148.0072
# Epoch 447/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 122.2485 - val_loss: 147.2358
# Epoch 448/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 121.2350 - val_loss: 146.7643
# Epoch 449/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 120.3094 - val_loss: 146.2459
# Epoch 450/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 119.3417 - val_loss: 145.3946
# Epoch 451/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 118.4674 - val_loss: 144.2769
# Epoch 452/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 117.4905 - val_loss: 143.3324
# Epoch 453/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 116.7325 - val_loss: 143.2736
# Epoch 454/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 115.7705 - val_loss: 142.4732
# Epoch 455/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 114.7976 - val_loss: 141.3122
# Epoch 456/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 113.9169 - val_loss: 140.7023
# Epoch 457/1000
# ...
# Epoch 652/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 37.9197 - val_loss: 79.5867
# Epoch 653/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 37.9695 - val_loss: 78.8551
# Epoch 654/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 37.6636 - val_loss: 77.9225
# Epoch 655/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 37.6977 - val_loss: 78.1492
# Epoch 656/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 37.4285 - val_loss: 78.4635
# Epoch 657/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 37.3522 - val_loss: 78.6557
# Epoch 658/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 37.3147 - val_loss: 77.7240
# Epoch 659/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 37.1678 - val_loss: 77.5928
# Epoch 660/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 37.0758 - val_loss: 78.0373
# Epoch 661/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 36.9114 - val_loss: 78.3853
# Epoch 662/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 36.9868 - val_loss: 77.2565
# Epoch 663/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 36.8584 - val_loss: 77.2270
# Epoch 664/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 36.6540 - val_loss: 77.6352
# Epoch 665/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 36.5141 - val_loss: 77.9355
# Epoch 666/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 36.5804 - val_loss: 77.0383
# Epoch 667/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 36.3917 - val_loss: 76.8944
# Epoch 668/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 36.2740 - val_loss: 77.3027
# Epoch 669/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 36.1675 - val_loss: 77.0651
# Epoch 670/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 36.1300 - val_loss: 76.8240
# Epoch 671/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 35.9819 - val_loss: 76.8914
# Epoch 672/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 35.8696 - val_loss: 77.2980
# Epoch 673/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 35.8794 - val_loss: 76.6354
# Epoch 674/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 35.7626 - val_loss: 76.4750
# Epoch 675/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 35.6558 - val_loss: 76.7783
# Epoch 676/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 35.6052 - val_loss: 76.5292
# Epoch 677/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 35.4763 - val_loss: 76.7058
# Epoch 678/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 35.4228 - val_loss: 76.2956
# Epoch 679/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 35.3189 - val_loss: 76.1197
# Epoch 680/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 35.2455 - val_loss: 76.0565
# Epoch 681/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 35.1609 - val_loss: 76.3095
# Epoch 682/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 35.0764 - val_loss: 76.3070
# Epoch 683/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 35.0310 - val_loss: 75.8486
# Epoch 684/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 34.9497 - val_loss: 76.0696
# Epoch 685/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.8370 - val_loss: 75.8880
# Epoch 686/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.7587 - val_loss: 75.5345
# Epoch 687/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.7768 - val_loss: 75.6928
# Epoch 688/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 34.6180 - val_loss: 76.0658
# Epoch 689/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 34.6551 - val_loss: 75.4663
# Epoch 690/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 34.5096 - val_loss: 75.4528
# Epoch 691/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.4259 - val_loss: 75.4202
# Epoch 692/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.3854 - val_loss: 75.6530
# Epoch 693/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 34.2795 - val_loss: 75.5325
# Epoch 694/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 34.1901 - val_loss: 75.3387
# Epoch 695/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 34.1917 - val_loss: 75.3099
# Epoch 696/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.1149 - val_loss: 75.0644
# Epoch 697/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 34.0566 - val_loss: 74.8995
# Epoch 698/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 34.0137 - val_loss: 75.2779
# Epoch 699/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 33.9147 - val_loss: 75.6210
# Epoch 700/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 33.9447 - val_loss: 75.1380
# Epoch 701/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 33.7643 - val_loss: 74.7073
# Epoch 702/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 33.7505 - val_loss: 74.8847
# Epoch 703/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.6323 - val_loss: 75.4826
# Epoch 704/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.7533 - val_loss: 74.7491
# Epoch 705/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.5603 - val_loss: 74.4614
# Epoch 706/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 33.5297 - val_loss: 74.9409
# Epoch 707/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 33.4425 - val_loss: 74.9872
# Epoch 708/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 33.3864 - val_loss: 74.4947
# Epoch 709/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.3365 - val_loss: 74.3592
# Epoch 710/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.3170 - val_loss: 74.4222
# Epoch 711/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.2271 - val_loss: 74.9765
# Epoch 712/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 33.3138 - val_loss: 74.1676
# Epoch 713/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 33.1244 - val_loss: 73.9118
# Epoch 714/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 33.1233 - val_loss: 74.2868
# Epoch 715/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 32.9992 - val_loss: 74.9478
# Epoch 716/1000
# 1/1 [==============================] - 0s 155ms/step - loss: 33.0381 - val_loss: 74.2778
# Epoch 717/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.9137 - val_loss: 73.7087
# Epoch 718/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.9511 - val_loss: 74.0812
# Epoch 719/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.8104 - val_loss: 74.6512
# Epoch 720/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 32.8646 - val_loss: 73.9493
# Epoch 721/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.7569 - val_loss: 73.9900
# Epoch 722/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.6502 - val_loss: 74.2027
# Epoch 723/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 32.6263 - val_loss: 73.9669
# Epoch 724/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 32.5674 - val_loss: 73.5771
# Epoch 725/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 32.6207 - val_loss: 73.9375
# Epoch 726/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 32.5001 - val_loss: 74.0584
# Epoch 727/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.4450 - val_loss: 73.7007
# Epoch 728/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 32.4653 - val_loss: 73.2871
# Epoch 729/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.4927 - val_loss: 73.4942
# Epoch 730/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.2929 - val_loss: 73.6446
# Epoch 731/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 32.3314 - val_loss: 73.4476
# Epoch 732/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.2286 - val_loss: 73.4908
# Epoch 733/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 32.1786 - val_loss: 73.4680
# Epoch 734/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 32.1828 - val_loss: 73.1991
# Epoch 735/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.1460 - val_loss: 73.3309
# Epoch 736/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.1036 - val_loss: 73.6021
# Epoch 737/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 32.0613 - val_loss: 73.3882
# Epoch 738/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 32.0222 - val_loss: 73.2359
# Epoch 739/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.9912 - val_loss: 73.4438
# Epoch 740/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.9731 - val_loss: 73.1562
# Epoch 741/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 31.9125 - val_loss: 73.1442
# Epoch 742/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 31.8681 - val_loss: 73.3922
# Epoch 743/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 31.8602 - val_loss: 73.3655
# Epoch 744/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 31.8314 - val_loss: 72.8425
# Epoch 745/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 31.8640 - val_loss: 73.2625
# Epoch 746/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 31.7010 - val_loss: 73.3285
# Epoch 747/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 31.7211 - val_loss: 73.0256
# Epoch 748/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 31.6646 - val_loss: 72.7958
# Epoch 749/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 31.6304 - val_loss: 73.1640
# Epoch 750/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 31.5667 - val_loss: 73.6033
# Epoch 751/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 31.6456 - val_loss: 72.7936
# Epoch 752/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 31.5267 - val_loss: 72.5963
# Epoch 753/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 31.6150 - val_loss: 73.4904
# Epoch 754/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 31.5481 - val_loss: 73.1524
# Epoch 755/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 31.4948 - val_loss: 72.6936
# Epoch 756/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 31.4031 - val_loss: 72.8491
# Epoch 757/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 31.3484 - val_loss: 73.0663
# Epoch 758/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 31.3709 - val_loss: 72.6857
# Epoch 759/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 31.3832 - val_loss: 73.1342
# Epoch 760/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 31.4083 - val_loss: 72.5494
# Epoch 761/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 31.3237 - val_loss: 72.7717
# Epoch 762/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 31.2601 - val_loss: 72.6673
# Epoch 763/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 31.2853 - val_loss: 72.9443
# Epoch 764/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.2573 - val_loss: 72.4659
# Epoch 765/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 31.1344 - val_loss: 72.3558
# Epoch 766/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.1483 - val_loss: 72.7337
# Epoch 767/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 31.1241 - val_loss: 72.4478
# Epoch 768/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.0972 - val_loss: 72.4790
# Epoch 769/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.0762 - val_loss: 72.6116
# Epoch 770/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 31.0470 - val_loss: 72.5048
# Epoch 771/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.0334 - val_loss: 71.9143
# Epoch 772/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.1146 - val_loss: 72.1741
# Epoch 773/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 31.0053 - val_loss: 73.5919
# Epoch 774/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 31.1628 - val_loss: 72.8018
# Epoch 775/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.9781 - val_loss: 71.7588
# Epoch 776/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.0162 - val_loss: 71.6996
# Epoch 777/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 31.2068 - val_loss: 73.1310
# Epoch 778/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.9665 - val_loss: 73.9066
# Epoch 779/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 31.2092 - val_loss: 71.9337
# Epoch 780/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 30.8331 - val_loss: 71.6323
# Epoch 781/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.3050 - val_loss: 73.0848
# Epoch 782/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 30.9105 - val_loss: 74.1552
# Epoch 783/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 31.2282 - val_loss: 72.0241
# Epoch 784/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.7162 - val_loss: 71.5237
# Epoch 785/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 31.2730 - val_loss: 72.3510
# Epoch 786/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.7404 - val_loss: 73.2121
# Epoch 787/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.8721 - val_loss: 72.2017
# Epoch 788/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 30.6304 - val_loss: 71.4986
# Epoch 789/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.9783 - val_loss: 72.1183
# Epoch 790/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.6569 - val_loss: 73.5030
# Epoch 791/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 31.0704 - val_loss: 71.8415
# Epoch 792/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.6570 - val_loss: 71.3899
# Epoch 793/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 31.0644 - val_loss: 72.3920
# Epoch 794/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.5874 - val_loss: 73.2606
# Epoch 795/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.7122 - val_loss: 72.1288
# Epoch 796/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.5314 - val_loss: 71.3361
# Epoch 797/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 30.9881 - val_loss: 71.9946
# Epoch 798/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.4639 - val_loss: 73.5712
# Epoch 799/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.8054 - val_loss: 72.2410
# Epoch 800/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 30.4390 - val_loss: 71.5097
# Epoch 801/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.4793 - val_loss: 71.5728
# Epoch 802/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.5338 - val_loss: 72.3885
# Epoch 803/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.4992 - val_loss: 72.0754
# Epoch 804/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 30.4239 - val_loss: 71.5267
# Epoch 805/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 30.4172 - val_loss: 71.7108
# Epoch 806/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 30.4249 - val_loss: 72.6772

# %%
def get_predictions(A, X):
    graph_conv_filters = preprocess_adj_tensor_by_filter(A, NUM_FILTERS, SYM_NORM)
    preds = model.predict([X, graph_conv_filters])
    if NB_BARABASI_PARAM == 2:
        # Round n and m to integers
        return np.rint(preds)
    elif NB_BARABASI_PARAM == 3:
        # Round n and m to integers
        Y_pred = np.zeros(preds.shape)
        Y_pred[:,:2] = np.rint(preds[:,:2])
        Y_pred[:,2] = preds[:,2]
        return Y_pred

def print_MSE(Y_true, Y_pred):
    if NB_BARABASI_PARAM == 2:
        print("n MSE: ", mean_squared_error(Y_true[:,0], Y_pred[:,0]))
        print("m MSE: ", mean_squared_error(Y_true[:,1], Y_pred[:,1]))
    elif NB_BARABASI_PARAM == 3:
        print("n MSE: ", mean_squared_error(Y_true[:,0], Y_pred[:,0]))
        print("m MSE: ", mean_squared_error(Y_true[:,1], Y_pred[:,1]))
        print("Alpha MSE: ", mean_squared_error(Y_true[:,2], Y_pred[:,2]))

# %% [markdown]
# ### Test network

# %%
# Load Test data
A_test, X_test, Y_test = load_our_data(
    "adjacency_matrices_test.csv",
    "feature_matrices_test.csv",
    "parameter_vectors_test.csv",
    seed=SEED,
)

# %% [markdown]
# #### Results from Table I

# %%
# Print Test MSE

Y_pred = get_predictions(A_test, X_test)
print_MSE(Y_test, Y_pred)
# Out:
# n MSE:  6.5
# m MSE:  182.75
# Alpha MSE:  2.743481946233676

# %%
if NB_BARABASI_PARAM == 3:
    plt.hist(Y_pred[:,2])

# %% [markdown]
# ### Plot learning curve

# %%
plt.plot(hist['loss'][5:], label='MSE training')
plt.plot(hist['val_loss'][5:], label='MSE validation')
plt.title('MSE during training')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Testing on Erdos-Reyni graphs

# %% [markdown]
# Goal: See whether our model predicts low values of alpha for ER graphs, since BA graphs with low alphas resemble ER
#
# Run only if NB_BARABASI_PARAM = 3

# %%
NB_ER = 1000

# %%
def generate_er_adj_matrix(n, p):
    """Generates an Erdos Renyi graph and returns an adjacency matrix with
     a node ordering defined by the networkx Graph library"""
    
    networkx_graph = nx.erdos_renyi_graph(n, p)
    adj_matrix = nx.linalg.graphmatrix.adjacency_matrix(networkx_graph, nodelist=None, weight=None)
    
    return adj_matrix.todense()

def generate_multi_er_graphs(nb_graphs, n):
    """Generates 'nb_graphs' ER graphs. Each graph has the same number of nodes 'n', the first 
    parameter of the ER model. The second parameter 'p' is randomly generated 
    in 0 <= p < 0.5. The function outputs the adjacency matrices, the feature matrices (identity matrices) 
    and the parameters n and m used in the data generation process"""
    
    # Each matrix generated during the graph generation process is vertically concatenated to the output
    adjacency_matrices = np.zeros((nb_graphs*n, n))
    feature_matrices = np.zeros((nb_graphs*n, n))
    parameter_vectors = np.zeros((nb_graphs, 2))

    for sample_graph_index in range(nb_graphs):
        
        # Choose p randomly
        p = np.random.uniform(0, 0.5)

        # Generate Barabasi Graph adjacency matrix
        adj_matrix = generate_er_adj_matrix(n, p)

        # Update output matrices
        row_start_index = n * sample_graph_index
        
        adjacency_matrices[row_start_index: row_start_index + n, :] = adj_matrix
        feature_matrices[row_start_index: row_start_index + n, :] = np.eye(n)
        parameter_vectors[sample_graph_index, :] = [n, p]
    
    return adjacency_matrices, feature_matrices, parameter_vectors

# %%
adjacency_matrices_er, feature_matrices_er, parameter_vectors_er = generate_multi_er_graphs(nb_graphs = NB_ER, n = NUMBER_OF_NODES)

# %%
np.savetxt('adjacency_matrices_er.csv', adjacency_matrices_er, delimiter=',')
np.savetxt('feature_matrices_er.csv', feature_matrices_er, delimiter=',')
np.savetxt('parameter_vectors_er.csv', parameter_vectors_er, delimiter=',')
A_er, X_er, Y_er = \
        load_our_data('adjacency_matrices_er.csv', 'feature_matrices_er.csv', 'parameter_vectors_er.csv',seed=SEED)

# %%
# Predictions on ER graphs
Y_pred_er = get_predictions(A_er, X_er)

plt.hist(Y_pred_er[:,2])
# Out:
# (array([ 12., 128., 321., 256., 122.,  63.,  42.,  25.,  20.,  11.]),
#  array([-0.60904348, -0.5992568 , -0.58947012, -0.57968345, -0.56989677,
#         -0.56011009, -0.55032341, -0.54053674, -0.53075006, -0.52096338,
#         -0.51117671]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Experiments

# %%
NUM_GRAPHS = 1000

# %%
def generate_graphs_from_params(n, m, alpha, num_graphs):
    """Generate num_graphs BA graphs with the given parameter values"""
    res = []
    for _ in range(num_graphs):
        res.append(barabasi_albert_graph(n,m,alpha))
    return res

def get_graphs(i, num_graphs, adj_test, y_pred):
    """Returns a graph representations of test graph with simulated graphs"""
    test_graph = adj_test[i]
    input_graph = nx.Graph(test_graph)
    params = y_pred[i,:]
    if NB_BARABASI_PARAM == 2:
        n,m = params
        alpha = 1
    elif NB_BARABASI_PARAM == 3:
        n,m,alpha = params
    if alpha <= 0: 
        alpha = 0.000000001
    output_graphs = generate_graphs_from_params(int(n), int(m), alpha, NUM_GRAPHS)
    return input_graph, output_graphs
    

def plot_scores(input_graphs, output_graphs, params, score_name="std_degree"):
    ncols = len(input_graphs)
    fig, axis = plt.subplots(1,ncols)
    
    scorer = GraphScorer()
    
    for idx,graph in enumerate(input_graphs):
        
        scores = [scorer.score(graph, score_name) for graph in output_graphs[idx]]
        input_score = scorer.score(graph, score_name)
        dist = sns.distplot(scores, ax=axis[idx],kde=False, norm_hist = True)#, color="dodgerblue", density = True)
        ymin, ymax = dist.get_ylim()
        axis[idx].vlines(input_score, ymin=ymin, ymax=ymax ,color="deeppink", label = "input")
        axis[idx].legend(loc = "upper right")
        if NB_BARABASI_PARAM == 2:
            textstr = '\n'.join((
                r'n=%.0f' % (int(params[idx][0]), ),
                r'm=%.0f' % (int(params[idx][1]), )))
        elif NB_BARABASI_PARAM == 3:
            textstr = '\n'.join((
                r'n=%.0f' % (int(params[idx][0]), ),
                r'm=%.0f' % (int(params[idx][1]), ),
                r'$\alpha=%.2f$' % (params[idx][2], )))
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
        axis[idx].text(0.05, 0.95, textstr, transform=axis[idx].transAxes, fontsize=12,
        verticalalignment='top', bbox=props)
    plt.suptitle("histogram for " + score_name)
    fig.set_figwidth(15)
    plt.show()

# %%
in_graphs, out_graphs, params = [],[],[]
# generate from three random test graphs
i1 = randint(0,Y_test.shape[0]-1)
i2 = randint(0,Y_test.shape[0]-1)
i3 = randint(0,Y_test.shape[0]-1)
for i in [i1,i2,i3]:
    cur_in, cur_out = get_graphs(i,NUM_GRAPHS,A_test,Y_pred)
    in_graphs.append(cur_in)
    out_graphs.append(cur_out)
    params.append(Y_test[i])

# %%
# Plot histograms

plot_scores(in_graphs, out_graphs, params)
plot_scores(in_graphs, out_graphs, params, "std_between_centrality")
plot_scores(in_graphs, out_graphs, params, "std_close_centrality")
plot_scores(in_graphs, out_graphs, params, "avg_degree")
plot_scores(in_graphs, out_graphs, params, "min_degree")
plot_scores(in_graphs, out_graphs, params, "max_degree")
plot_scores(in_graphs, out_graphs, params, "avg_between_centrality")
plot_scores(in_graphs, out_graphs, params, "avg_close_centrality")
plot_scores(in_graphs, out_graphs, params, "num_triangles")
# Out:
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /Users/andreasopedal/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Plotting Barabasi-Albert graphs

# %%
def draw_random_ba_graphs(n, m, alpha, nrows=2, ncols=2,param='alpha',save=False):
 
    graphs = [barabasi_albert_graph(n, m, alpha) for idx in range(nrows * ncols)]
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols)
    ax = axes.flatten()
    for i in range(nrows * ncols):
        d = dict(graphs[i].degree)
        nx.draw_kamada_kawai(
            graphs[i],
            ax=ax[i],
            node_color="orchid",
            edge_color="grey",
            nodelist=d.keys(),
            node_size=[v**1.8  for v in d.values()],
            #node_color=range(n),
            cmap=plt.get_cmap('Greys')
        )
        #if param == 'alpha':
         #   ax[i].set_title(f'{param}={np.round(alpha,decimals=2)}')
        #elif param == 'm':
         #   ax[i].set_title(f'{param}={m}')
        #ax[i].set_axis_off()
    if param == 'alpha':
        fig.suptitle(f"{param}={np.round(alpha,decimals=2)}")
    elif param == 'm':
         fig.suptitle(f"{param}={np.round(m,decimals=2)}")
    
    if save:
        plt.savefig(f"BA_n_{n}_m_{m}_alpha_{alpha}.png")
    plt.show()

# %%
def draw_ba_graphs_alphas(n, m, alphas, nrows=1, ncols=3,param='alpha',save=False):
 
    graphs = [barabasi_albert_graph(n, m, alphas[i]) for i in range(len(alphas))]
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols,figsize=(10,3))
    ax = axes.flatten()
    for i in range(len(alphas)):
        d = dict(graphs[i].degree)
        nx.draw_kamada_kawai(
            graphs[i],
            ax=ax[i],
            node_color="orchid",
            edge_color="grey",
            nodelist=d.keys(),
            node_size=[v**1.8  for v in d.values()],
            #node_color=range(n),
            cmap=plt.get_cmap('Greys')
        )
        ax[i].set_title(r'$\alpha=$'+f'{np.round(alphas[i],decimals=2)}')
       
        #ax[i].set_axis_off()
   
    if save:
        plt.savefig(f"BA_n_{n}_m_{m}_alphas_{alphas}.png")
    plt.show()

# %%
alphas=[1/3,1,3]
draw_ba_graphs_alphas(n=20,m=5,alphas=alphas,ncols=3,param='alpha',save=False)
